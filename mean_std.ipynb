# %%
# https://github.com/wenwei202/pytorch-examples/blob/autogrow/cifar10/get_mean_std.py

from collections import defaultdict
from PIL import Image
from torch.utils.data import Dataset, DataLoader

import json
import matplotlib.pyplot as plt
import numpy as np
import os
import torch
import torchvision.transforms as transforms

# %%
# !python test_final.py
# Out:
# Number of total samples = 1000
# Number of model parameters - 48571057
# 32it [00:50,  1.58s/it]
# Number of Unique original objects:  1000
# Stacked Pred shape - torch.Size([1000, 160, 240])
# Stacked GT shape - torch.Size([1000, 160, 240])
# Truth: cube_rbr_yllw, Predicted: background, Errors: 31212
# Truth: cyl_rbr_gry, Predicted: background, Errors: 28708
# Truth: cyl_mtl_red, Predicted: background, Errors: 28587
# Truth: cube_mtl_grn, Predicted: background, Errors: 26758
# Truth: cube_rbr_blu, Predicted: background, Errors: 26399
# Truth: cyl_mtl_prple, Predicted: background, Errors: 26106
# Truth: cube_rbr_cyan, Predicted: background, Errors: 25667
# Truth: cube_mtl_prple, Predicted: background, Errors: 25640
# Truth: cyl_rbr_red, Predicted: background, Errors: 25115
# Truth: cube_mtl_red, Predicted: background, Errors: 25083
# Truth: cube_rbr_red, Predicted: background, Errors: 25003
# Truth: cyl_mtl_gry, Predicted: background, Errors: 24865
# Truth: cube_mtl_blu, Predicted: background, Errors: 24505
# Truth: cyl_mtl_cyan, Predicted: background, Errors: 24366
# Truth: cyl_rbr_blu, Predicted: background, Errors: 24258
# Truth: cyl_mtl_brwn, Predicted: background, Errors: 24122
# Truth: cyl_rbr_brwn, Predicted: background, Errors: 23962
# Truth: cyl_mtl_grn, Predicted: background, Errors: 23733
# Truth: cube_mtl_brwn, Predicted: background, Errors: 23597
# Truth: cube_rbr_prple, Predicted: background, Errors: 23499
# Truth: cyl_rbr_yllw, Predicted: background, Errors: 23133
# Truth: cube_mtl_gry, Predicted: background, Errors: 22899
# Truth: cyl_rbr_cyan, Predicted: background, Errors: 22893
# Truth: cyl_mtl_blu, Predicted: background, Errors: 22321
# Truth: cube_mtl_yllw, Predicted: background, Errors: 22145
# Truth: cyl_mtl_yllw, Predicted: background, Errors: 22113
# Truth: cube_rbr_brwn, Predicted: background, Errors: 21647
# Truth: cyl_rbr_prple, Predicted: background, Errors: 20831
# Truth: sph_mtl_blu, Predicted: background, Errors: 20381
# Truth: sph_rbr_gry, Predicted: background, Errors: 20364
# Truth: sph_mtl_brwn, Predicted: background, Errors: 20184
# Truth: cube_mtl_cyan, Predicted: background, Errors: 20096
# Truth: cyl_rbr_grn, Predicted: background, Errors: 19606
# Truth: sph_mtl_prple, Predicted: background, Errors: 19170
# Truth: sph_rbr_yllw, Predicted: background, Errors: 19098
# Truth: sph_mtl_grn, Predicted: background, Errors: 19071
# Truth: sph_mtl_gry, Predicted: background, Errors: 18638
# Truth: sph_rbr_prple, Predicted: background, Errors: 18315
# Truth: cube_rbr_gry, Predicted: background, Errors: 18254
# Truth: cube_rbr_grn, Predicted: background, Errors: 18250
# Truth: sph_rbr_grn, Predicted: background, Errors: 17912
# Truth: sph_rbr_cyan, Predicted: background, Errors: 17869
# Truth: sph_mtl_cyan, Predicted: background, Errors: 17793
# Truth: sph_mtl_red, Predicted: background, Errors: 17623
# Truth: sph_rbr_blu, Predicted: background, Errors: 17497
# Truth: sph_rbr_red, Predicted: background, Errors: 16993
# Truth: sph_rbr_brwn, Predicted: background, Errors: 16097
# Truth: sph_mtl_yllw, Predicted: background, Errors: 13038
# Truth: background, Predicted: cube_rbr_grn, Errors: 8461
# Truth: cube_mtl_red, Predicted: cyl_mtl_red, Errors: 7648
# Truth: background, Predicted: cube_mtl_grn, Errors: 6897
# Truth: cube_mtl_brwn, Predicted: cyl_mtl_brwn, Errors: 6348
# Truth: cyl_mtl_brwn, Predicted: cube_mtl_brwn, Errors: 5986
# Truth: cyl_mtl_cyan, Predicted: cube_mtl_cyan, Errors: 5810
# Truth: cube_rbr_yllw, Predicted: cyl_rbr_yllw, Errors: 5794
# Truth: cyl_rbr_gry, Predicted: cube_rbr_gry, Errors: 5684
# Truth: cyl_rbr_brwn, Predicted: cube_rbr_brwn, Errors: 5649
# Truth: background, Predicted: cube_mtl_gry, Errors: 5631
# Truth: background, Predicted: cyl_mtl_red, Errors: 5628
# Truth: cube_mtl_blu, Predicted: cyl_mtl_blu, Errors: 5600
# Truth: cyl_mtl_grn, Predicted: cube_mtl_grn, Errors: 5589
# Truth: background, Predicted: cyl_rbr_cyan, Errors: 5565
# Truth: background, Predicted: cube_rbr_cyan, Errors: 5481
# Truth: cube_rbr_gry, Predicted: cyl_rbr_gry, Errors: 5472
# Truth: background, Predicted: cyl_mtl_brwn, Errors: 5414
# Truth: cube_mtl_yllw, Predicted: cyl_mtl_yllw, Errors: 5393
# Truth: cube_rbr_grn, Predicted: cyl_rbr_grn, Errors: 5304
# Truth: background, Predicted: cube_rbr_blu, Errors: 5289
# Truth: background, Predicted: cube_mtl_prple, Errors: 5287
# Truth: cube_rbr_cyan, Predicted: cyl_rbr_cyan, Errors: 5255
# Truth: cube_rbr_prple, Predicted: cyl_rbr_prple, Errors: 5211
# Truth: background, Predicted: cube_mtl_cyan, Errors: 5189
# Truth: cube_rbr_brwn, Predicted: cyl_rbr_brwn, Errors: 5158
# Truth: background, Predicted: cube_rbr_red, Errors: 5048
# Truth: background, Predicted: cube_mtl_red, Errors: 5046
# Truth: background, Predicted: cyl_rbr_gry, Errors: 4751
# Truth: background, Predicted: cyl_mtl_gry, Errors: 4710
# Truth: background, Predicted: cube_rbr_prple, Errors: 4558
# Truth: cube_mtl_prple, Predicted: cyl_mtl_prple, Errors: 4536
# Truth: background, Predicted: cyl_rbr_red, Errors: 4521
# Truth: cyl_rbr_blu, Predicted: cube_rbr_blu, Errors: 4371
# Truth: cyl_rbr_grn, Predicted: cube_rbr_grn, Errors: 4347
# Truth: cube_rbr_blu, Predicted: cyl_rbr_blu, Errors: 4305
# Truth: background, Predicted: cyl_mtl_yllw, Errors: 4274
# Truth: cyl_mtl_gry, Predicted: cube_mtl_gry, Errors: 4265
# Truth: cyl_rbr_red, Predicted: cube_rbr_red, Errors: 4256
# Truth: background, Predicted: cube_rbr_yllw, Errors: 4250
# Truth: cube_rbr_red, Predicted: cyl_rbr_red, Errors: 4232
# Truth: cube_mtl_cyan, Predicted: cyl_mtl_cyan, Errors: 4162
# Truth: background, Predicted: cyl_rbr_prple, Errors: 4115
# Truth: background, Predicted: cyl_rbr_blu, Errors: 4023
# Truth: cyl_mtl_yllw, Predicted: cube_mtl_yllw, Errors: 3957
# Truth: cyl_rbr_cyan, Predicted: cube_rbr_cyan, Errors: 3860
# Truth: cyl_mtl_prple, Predicted: cube_mtl_prple, Errors: 3844
# Truth: background, Predicted: cube_rbr_gry, Errors: 3820
# Truth: background, Predicted: cyl_rbr_brwn, Errors: 3771
# Truth: background, Predicted: cube_rbr_brwn, Errors: 3769
# Truth: background, Predicted: cyl_mtl_blu, Errors: 3767
# Truth: background, Predicted: cyl_mtl_prple, Errors: 3700
# Truth: background, Predicted: cyl_mtl_cyan, Errors: 3676
# Truth: cyl_rbr_yllw, Predicted: cube_rbr_yllw, Errors: 3674
# Truth: cube_mtl_gry, Predicted: cyl_mtl_gry, Errors: 3430
# Truth: background, Predicted: cyl_mtl_grn, Errors: 3393
# Truth: cyl_mtl_blu, Predicted: cube_mtl_blu, Errors: 3380
# Truth: background, Predicted: cube_mtl_yllw, Errors: 3379
# Truth: background, Predicted: cyl_rbr_grn, Errors: 3365
# Truth: background, Predicted: cube_mtl_blu, Errors: 3357
# Truth: background, Predicted: cube_mtl_brwn, Errors: 3299
# Truth: cyl_rbr_prple, Predicted: cube_rbr_prple, Errors: 3267
# Truth: background, Predicted: sph_mtl_blu, Errors: 3091
# Truth: background, Predicted: sph_mtl_gry, Errors: 3083
# Truth: background, Predicted: cyl_rbr_yllw, Errors: 2962
# Truth: background, Predicted: sph_mtl_red, Errors: 2947
# Truth: background, Predicted: sph_rbr_grn, Errors: 2811
# Truth: background, Predicted: sph_mtl_prple, Errors: 2780
# Truth: background, Predicted: sph_rbr_cyan, Errors: 2293
# Truth: cyl_mtl_red, Predicted: cube_mtl_red, Errors: 2145
# Truth: background, Predicted: sph_mtl_grn, Errors: 2145
# Truth: cube_mtl_grn, Predicted: cyl_mtl_grn, Errors: 2092
# Truth: background, Predicted: sph_rbr_blu, Errors: 2027
# Truth: background, Predicted: sph_rbr_yllw, Errors: 1955
# Truth: background, Predicted: sph_mtl_yllw, Errors: 1933
# Truth: background, Predicted: sph_mtl_cyan, Errors: 1928
# Truth: background, Predicted: sph_rbr_gry, Errors: 1914
# Truth: background, Predicted: sph_mtl_brwn, Errors: 1831
# Truth: background, Predicted: sph_rbr_prple, Errors: 1703
# Truth: background, Predicted: sph_rbr_brwn, Errors: 1563
# Truth: background, Predicted: sph_rbr_red, Errors: 1485
# Images that need fixing :  924
# Truth: cube_rbr_yllw, Predicted: background, Errors: 37940
# Truth: cyl_rbr_gry, Predicted: background, Errors: 35223
# Truth: cube_mtl_red, Predicted: background, Errors: 33199
# Truth: cyl_mtl_red, Predicted: background, Errors: 31924
# Truth: cyl_mtl_prple, Predicted: background, Errors: 31568
# Truth: cube_mtl_prple, Predicted: background, Errors: 31054
# Truth: cyl_rbr_red, Predicted: background, Errors: 31047
# Truth: cube_mtl_brwn, Predicted: background, Errors: 30934
# Truth: cube_mtl_blu, Predicted: background, Errors: 30910
# Truth: cube_rbr_cyan, Predicted: background, Errors: 30882
# Truth: cube_rbr_blu, Predicted: background, Errors: 30660
# Truth: cyl_mtl_brwn, Predicted: background, Errors: 30565
# Truth: cyl_mtl_cyan, Predicted: background, Errors: 30509
# Truth: cube_mtl_grn, Predicted: background, Errors: 30361
# Truth: cyl_rbr_brwn, Predicted: background, Errors: 30206
# Truth: cyl_mtl_grn, Predicted: background, Errors: 30096
# Truth: cube_rbr_prple, Predicted: background, Errors: 29635
# Truth: cube_rbr_red, Predicted: background, Errors: 29553
# Truth: cyl_rbr_blu, Predicted: background, Errors: 29463
# Truth: cyl_mtl_gry, Predicted: background, Errors: 29226
# Truth: cube_mtl_yllw, Predicted: background, Errors: 28095
# Truth: cube_rbr_brwn, Predicted: background, Errors: 27275
# Truth: cyl_rbr_yllw, Predicted: background, Errors: 27248
# Truth: cyl_rbr_cyan, Predicted: background, Errors: 26892
# Truth: cube_mtl_gry, Predicted: background, Errors: 26513
# Truth: cyl_mtl_blu, Predicted: background, Errors: 26248
# Truth: cyl_mtl_yllw, Predicted: background, Errors: 25844
# Truth: cyl_rbr_prple, Predicted: background, Errors: 25355
# Truth: cyl_rbr_grn, Predicted: background, Errors: 24992
# Truth: cube_mtl_cyan, Predicted: background, Errors: 24576
# Truth: cube_rbr_gry, Predicted: background, Errors: 24469
# Truth: cube_rbr_grn, Predicted: background, Errors: 23897
# Truth: sph_mtl_blu, Predicted: background, Errors: 21388
# Truth: sph_mtl_brwn, Predicted: background, Errors: 21140
# Truth: sph_rbr_gry, Predicted: background, Errors: 20879
# Truth: sph_mtl_grn, Predicted: background, Errors: 20230
# Truth: sph_rbr_yllw, Predicted: background, Errors: 20104
# Truth: sph_rbr_prple, Predicted: background, Errors: 19857
# Truth: sph_mtl_prple, Predicted: background, Errors: 19823
# Truth: sph_mtl_gry, Predicted: background, Errors: 19565
# Truth: sph_rbr_grn, Predicted: background, Errors: 19274
# Truth: sph_rbr_cyan, Predicted: background, Errors: 19017
# Truth: sph_mtl_red, Predicted: background, Errors: 18818
# Truth: sph_mtl_cyan, Predicted: background, Errors: 18676
# Truth: sph_rbr_blu, Predicted: background, Errors: 18290
# Truth: sph_rbr_red, Predicted: background, Errors: 17718
# Truth: sph_rbr_brwn, Predicted: background, Errors: 17012
# Truth: sph_mtl_yllw, Predicted: background, Errors: 13669
# Truth: background, Predicted: cube_mtl_grn, Errors: 5146
# Truth: background, Predicted: cyl_rbr_cyan, Errors: 4449
# Truth: background, Predicted: cube_mtl_red, Errors: 4125
# Truth: background, Predicted: cube_rbr_blu, Errors: 4076
# Truth: background, Predicted: cube_mtl_prple, Errors: 4044
# Truth: background, Predicted: cyl_mtl_gry, Errors: 3921
# Truth: background, Predicted: cyl_mtl_brwn, Errors: 3864
# Truth: background, Predicted: cube_rbr_cyan, Errors: 3828
# Truth: background, Predicted: cube_rbr_yllw, Errors: 3600
# Truth: background, Predicted: cube_mtl_gry, Errors: 3534
# Truth: background, Predicted: cyl_mtl_red, Errors: 3518
# Truth: background, Predicted: cyl_rbr_gry, Errors: 3310
# Truth: background, Predicted: cube_rbr_prple, Errors: 3242
# Truth: background, Predicted: cube_rbr_red, Errors: 3088
# Truth: background, Predicted: cyl_mtl_yllw, Errors: 2985
# Truth: background, Predicted: cyl_rbr_brwn, Errors: 2876
# Truth: background, Predicted: cyl_mtl_cyan, Errors: 2755
# Truth: background, Predicted: sph_mtl_blu, Errors: 2752
# Truth: background, Predicted: cyl_rbr_red, Errors: 2750
# Truth: background, Predicted: sph_mtl_gry, Errors: 2733
# Truth: background, Predicted: cube_mtl_cyan, Errors: 2669
# Truth: background, Predicted: cyl_mtl_grn, Errors: 2543
# Truth: background, Predicted: sph_mtl_red, Errors: 2403
# Truth: background, Predicted: cube_rbr_gry, Errors: 2392
# Truth: background, Predicted: cyl_rbr_blu, Errors: 2352
# Truth: background, Predicted: cyl_mtl_prple, Errors: 2294
# Truth: background, Predicted: cube_mtl_blu, Errors: 2275
# Truth: background, Predicted: sph_rbr_grn, Errors: 2272
# Truth: background, Predicted: cube_rbr_grn, Errors: 2262
# Truth: background, Predicted: cube_mtl_yllw, Errors: 2256
# Truth: background, Predicted: cyl_mtl_blu, Errors: 2172
# Truth: background, Predicted: sph_mtl_grn, Errors: 2109
# Truth: background, Predicted: sph_rbr_cyan, Errors: 2102
# Truth: background, Predicted: cube_rbr_brwn, Errors: 2067
# Truth: background, Predicted: cyl_rbr_grn, Errors: 2055
# Truth: background, Predicted: cube_mtl_brwn, Errors: 2009
# Truth: background, Predicted: cyl_rbr_prple, Errors: 1992
# Truth: background, Predicted: sph_mtl_prple, Errors: 1950
# Truth: background, Predicted: cyl_rbr_yllw, Errors: 1913
# Truth: background, Predicted: sph_rbr_blu, Errors: 1907
# Truth: background, Predicted: sph_rbr_gry, Errors: 1807
# Truth: background, Predicted: sph_rbr_yllw, Errors: 1785
# Truth: background, Predicted: sph_mtl_yllw, Errors: 1637
# Truth: background, Predicted: sph_mtl_brwn, Errors: 1625
# Truth: background, Predicted: sph_mtl_cyan, Errors: 1573
# Truth: background, Predicted: sph_rbr_prple, Errors: 1563
# Truth: cyl_mtl_brwn, Predicted: cube_mtl_brwn, Errors: 1391
# Truth: background, Predicted: sph_rbr_brwn, Errors: 1317
# Truth: cyl_mtl_gry, Predicted: cube_mtl_gry, Errors: 1252
# Truth: background, Predicted: sph_rbr_red, Errors: 1096
# Jaccard of predicted with gt:  tensor(0.3480)
# Jaccard of predicted with gt after heuristics:  tensor(0.3786)
# Jaccard of gt with gt:  tensor(1.)

# %%
class TestDataset(Dataset):
    
    def __init__(self, data_dir = './data/'):
        self.data_dir = data_dir
        
        self.path = self.data_dir + "unlabeled"
        self.video_paths = [os.path.join(self.path, v) for v in os.listdir(self.path) if os.path.isdir(os.path.join(self.path, v))]
        self.path = self.data_dir + "train"
        self.video_paths = self.video_paths + [os.path.join(self.path, v) for v in os.listdir(self.path) if os.path.isdir(os.path.join(self.path, v))]
        self.video_paths.sort()
        
        # Had issues with these files locally, seem corrupted
#         self.video_paths.remove('./data/unlabeled/video_14879')
#         self.video_paths.remove('./data/unlabeled/video_3110')
        self.video_paths.remove('./data/unlabeled/video_3768')
        self.video_paths.remove('./data/unlabeled/video_3776')
#         self.video_paths.remove('./data/unlabeled/video_6751')
#         self.video_paths.remove('./data/unlabeled/video_6814')
        
        self.transform = transforms.Compose([
            transforms.ToTensor()
        ])
    
    def __len__(self):
        return len(self.video_paths)
    
    def __getitem__(self, index):
        video_path = self.video_paths[index]

        images = []
        for idx in np.arange(22):
            img_path = os.path.join(video_path, f"image_{idx}.png")
            img = self.transform(Image.open(img_path))
            images.append(img)
        image_tensor = torch.stack(images, dim = 0)
        
        return image_tensor, video_path

# %%
trainset = TestDataset()

trainloader = torch.utils.data.DataLoader(trainset, batch_size=1, num_workers=2)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
h, w = 0, 0
for batch_idx, (inputs, vpath) in enumerate(trainloader):
    
    if (batch_idx+1) % 100 == 0:
        print(f"Completed mean for {(batch_idx+1)} videos!")
    
    inputs = inputs.to(device)
    inputs = inputs.squeeze()
    if batch_idx == 0:
        h, w = inputs.size(2), inputs.size(3)
        print(inputs.min(), inputs.max())
        chsum = inputs.sum(dim=(0, 2, 3), keepdim=True)
    else:
        chsum += inputs.sum(dim=(0, 2, 3), keepdim=True)
mean = chsum/(len(trainset) * 22)/h/w
print('mean: %s' % mean.view(-1))

chsum = None
for batch_idx, (inputs, vpath) in enumerate(trainloader):
    
    if (batch_idx+1) % 100 == 0:
        print(f"Completed std for {(batch_idx+1)} videos!")
        
    inputs = inputs.to(device)
    inputs = inputs.squeeze()
    if batch_idx == 0:
        chsum = (inputs - mean).pow(2).sum(dim=(0, 2, 3), keepdim=True)
    else:
        chsum += (inputs - mean).pow(2).sum(dim=(0, 2, 3), keepdim=True)
std = torch.sqrt(chsum/(len(trainset) * 22 * h * w - 1))
print('std: %s' % std.view(-1))

print('Done!')
# Out:
# tensor(0.) tensor(1.)
# Completed mean for 100 videos!
# Completed mean for 200 videos!
# Completed mean for 300 videos!
# Completed mean for 400 videos!
# Completed mean for 500 videos!
# Completed mean for 600 videos!
# Completed mean for 700 videos!
# Completed mean for 800 videos!
# Completed mean for 900 videos!
# Completed mean for 1000 videos!
# Completed mean for 1100 videos!
# Completed mean for 1200 videos!
# Completed mean for 1300 videos!
# Completed mean for 1400 videos!
# Completed mean for 1500 videos!
# Completed mean for 1600 videos!
# Completed mean for 1700 videos!
# Completed mean for 1800 videos!
# Completed mean for 1900 videos!
# Completed mean for 2000 videos!
# Completed mean for 2100 videos!
# Completed mean for 2200 videos!
# Completed mean for 2300 videos!
# Completed mean for 2400 videos!
# Completed mean for 2500 videos!
# Completed mean for 2600 videos!
# Completed mean for 2700 videos!
# Completed mean for 2800 videos!
# Completed mean for 2900 videos!
# Completed mean for 3000 videos!
# Completed mean for 3100 videos!
# Completed mean for 3200 videos!
# Completed mean for 3300 videos!
# Completed mean for 3400 videos!
# Completed mean for 3500 videos!
# Completed mean for 3600 videos!
# Completed mean for 3700 videos!
# Completed mean for 3800 videos!
# Completed mean for 3900 videos!
# Completed mean for 4000 videos!
# Completed mean for 4100 videos!
# Completed mean for 4200 videos!
# Completed mean for 4300 videos!
# Completed mean for 4400 videos!
# Completed mean for 4500 videos!
# Completed mean for 4600 videos!
# Completed mean for 4700 videos!
# Completed mean for 4800 videos!
# Completed mean for 4900 videos!
# Completed mean for 5000 videos!
# Completed mean for 5100 videos!
# Completed mean for 5200 videos!
# Completed mean for 5300 videos!
# Completed mean for 5400 videos!
# Completed mean for 5500 videos!
# Completed mean for 5600 videos!
# Completed mean for 5700 videos!
# Completed mean for 5800 videos!
# Completed mean for 5900 videos!
# Completed mean for 6000 videos!
# Completed mean for 6100 videos!
# Completed mean for 6200 videos!
# Completed mean for 6300 videos!
# Completed mean for 6400 videos!
# Completed mean for 6500 videos!
# Completed mean for 6600 videos!
# Completed mean for 6700 videos!
# Completed mean for 6800 videos!
# Completed mean for 6900 videos!
# Completed mean for 7000 videos!
# Completed mean for 7100 videos!
# Completed mean for 7200 videos!
# Completed mean for 7300 videos!
# Completed mean for 7400 videos!
# Completed mean for 7500 videos!
# Completed mean for 7600 videos!
# Completed mean for 7700 videos!
# Completed mean for 7800 videos!
# Completed mean for 7900 videos!
# Completed mean for 8000 videos!
# Completed mean for 8100 videos!
# Completed mean for 8200 videos!
# Completed mean for 8300 videos!
# Completed mean for 8400 videos!
# Completed mean for 8500 videos!
# Completed mean for 8600 videos!
# Completed mean for 8700 videos!
# Completed mean for 8800 videos!
# Completed mean for 8900 videos!
# Completed mean for 9000 videos!
# Completed mean for 9100 videos!
# Completed mean for 9200 videos!
# Completed mean for 9300 videos!
# Completed mean for 9400 videos!
# Completed mean for 9500 videos!
# Completed mean for 9600 videos!
# Completed mean for 9700 videos!
# Completed mean for 9800 videos!
# Completed mean for 9900 videos!
# Completed mean for 10000 videos!
# Completed mean for 10100 videos!
# Completed mean for 10200 videos!
# Completed mean for 10300 videos!
# Completed mean for 10400 videos!
# Completed mean for 10500 videos!
# Completed mean for 10600 videos!
# Completed mean for 10700 videos!
# Completed mean for 10800 videos!
# Completed mean for 10900 videos!
# Completed mean for 11000 videos!
# Completed mean for 11100 videos!
# Completed mean for 11200 videos!
# Completed mean for 11300 videos!
# Completed mean for 11400 videos!
# Completed mean for 11500 videos!
# Completed mean for 11600 videos!
# Completed mean for 11700 videos!
# Completed mean for 11800 videos!
# Completed mean for 11900 videos!
# Completed mean for 12000 videos!
# Completed mean for 12100 videos!
# Completed mean for 12200 videos!
# Completed mean for 12300 videos!
# Completed mean for 12400 videos!
# Completed mean for 12500 videos!
# Completed mean for 12600 videos!
# Completed mean for 12700 videos!
# Completed mean for 12800 videos!
# Completed mean for 12900 videos!
# Completed mean for 13000 videos!
# Completed mean for 13100 videos!
# Completed mean for 13200 videos!
# Completed mean for 13300 videos!
# Completed mean for 13400 videos!
# Completed mean for 13500 videos!
# Completed mean for 13600 videos!
# Completed mean for 13700 videos!
# Completed mean for 13800 videos!
# Completed mean for 13900 videos!
# mean: tensor([0.5061, 0.5045, 0.5008])
# Completed std for 100 videos!
# Completed std for 200 videos!
# Completed std for 300 videos!
# Completed std for 400 videos!
# Completed std for 500 videos!
# Completed std for 600 videos!
# Completed std for 700 videos!
# Completed std for 800 videos!
# Completed std for 900 videos!
# Completed std for 1000 videos!
# Completed std for 1100 videos!
# Completed std for 1200 videos!
# Completed std for 1300 videos!
# Completed std for 1400 videos!
# Completed std for 1500 videos!
# Completed std for 1600 videos!
# Completed std for 1700 videos!
# Completed std for 1800 videos!
# Completed std for 1900 videos!
# Completed std for 2000 videos!
# Completed std for 2100 videos!
# Completed std for 2200 videos!
# Completed std for 2300 videos!
# Completed std for 2400 videos!
# Completed std for 2500 videos!
# Completed std for 2600 videos!
# Completed std for 2700 videos!
# Completed std for 2800 videos!
# Completed std for 2900 videos!
# Completed std for 3000 videos!
# Completed std for 3100 videos!
# Completed std for 3200 videos!
# Completed std for 3300 videos!
# Completed std for 3400 videos!
# Completed std for 3500 videos!
# Completed std for 3600 videos!
# Completed std for 3700 videos!
# Completed std for 3800 videos!
# Completed std for 3900 videos!
# Completed std for 4000 videos!
# Completed std for 4100 videos!
# Completed std for 4200 videos!
# Completed std for 4300 videos!
# Completed std for 4400 videos!
# Completed std for 4500 videos!
# Completed std for 4600 videos!
# Completed std for 4700 videos!
# Completed std for 4800 videos!
# Completed std for 4900 videos!
# Completed std for 5000 videos!
# Completed std for 5100 videos!
# Completed std for 5200 videos!
# Completed std for 5300 videos!
# Completed std for 5400 videos!
# Completed std for 5500 videos!
# Completed std for 5600 videos!
# Completed std for 5700 videos!
# Completed std for 5800 videos!
# Completed std for 5900 videos!
# Completed std for 6000 videos!
# Completed std for 6100 videos!
# Completed std for 6200 videos!
# Completed std for 6300 videos!
# Completed std for 6400 videos!
# Completed std for 6500 videos!
# Completed std for 6600 videos!
# Completed std for 6700 videos!
# Completed std for 6800 videos!
# Completed std for 6900 videos!
# Completed std for 7000 videos!
# Completed std for 7100 videos!
# Completed std for 7200 videos!
# Completed std for 7300 videos!
# Completed std for 7400 videos!
# Completed std for 7500 videos!
# Completed std for 7600 videos!
# Completed std for 7700 videos!
# Completed std for 7800 videos!
# Completed std for 7900 videos!
# Completed std for 8000 videos!
# Completed std for 8100 videos!
# Completed std for 8200 videos!
# Completed std for 8300 videos!
# Completed std for 8400 videos!
# Completed std for 8500 videos!
# Completed std for 8600 videos!
# Completed std for 8700 videos!
# Completed std for 8800 videos!
# Completed std for 8900 videos!
# Completed std for 9000 videos!
# Completed std for 9100 videos!
# Completed std for 9200 videos!
# Completed std for 9300 videos!
# Completed std for 9400 videos!
# Completed std for 9500 videos!
# Completed std for 9600 videos!
# Completed std for 9700 videos!
# Completed std for 9800 videos!
# Completed std for 9900 videos!
# Completed std for 10000 videos!
# Completed std for 10100 videos!
# Completed std for 10200 videos!
# Completed std for 10300 videos!
# Completed std for 10400 videos!
# Completed std for 10500 videos!
# Completed std for 10600 videos!
# Completed std for 10700 videos!
# Completed std for 10800 videos!
# Completed std for 10900 videos!
# Completed std for 11000 videos!
# Completed std for 11100 videos!
# Completed std for 11200 videos!
# Completed std for 11300 videos!
# Completed std for 11400 videos!
# Completed std for 11500 videos!
# Completed std for 11600 videos!
# Completed std for 11700 videos!
# Completed std for 11800 videos!
# Completed std for 11900 videos!
# Completed std for 12000 videos!
# Completed std for 12100 videos!
# Completed std for 12200 videos!
# Completed std for 12300 videos!
# Completed std for 12400 videos!
# Completed std for 12500 videos!
# Completed std for 12600 videos!
# Completed std for 12700 videos!
# Completed std for 12800 videos!
# Completed std for 12900 videos!
# Completed std for 13000 videos!
# Completed std for 13100 videos!
# Completed std for 13200 videos!
# Completed std for 13300 videos!
# Completed std for 13400 videos!
# Completed std for 13500 videos!
# Completed std for 13600 videos!
# Completed std for 13700 videos!
# Completed std for 13800 videos!
# Completed std for 13900 videos!
# std: tensor([0.0571, 0.0567, 0.0614])
# Done!
